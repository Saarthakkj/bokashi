# %%
# sudo apt install tesseract-ocr
# sudo apt install libtesseract-dev
# pip install presidio_analyzer
# %pip install presidio_anonymizer
# python -m spacy download en_core_web_lg
# %pip install presidio-image-redactor
# python -m spacy download en_core_web_lg
# Out:
# Requirement already satisfied: presidio_anonymizer in c:\users\saarthak\anaconda3\lib\site-packages (2.2.357)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: azure-core in c:\users\saarthak\anaconda3\lib\site-packages (from presidio_anonymizer) (1.32.0)
# Requirement already satisfied: pycryptodome>=3.10.1 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio_anonymizer) (3.22.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from azure-core->presidio_anonymizer) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-core->presidio_anonymizer) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-core->presidio_anonymizer) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from requests>=2.21.0->azure-core->presidio_anonymizer) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saarthak\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core->presidio_anonymizer) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saarthak\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core->presidio_anonymizer) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from requests>=2.21.0->azure-core->presidio_anonymizer) (2024.2.2)
# Collecting presidio-image-redactorNote: you may need to restart the kernel to use updated packages.
#
#   Using cached presidio_image_redactor-0.0.55-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: azure-ai-formrecognizer<4.0.0,>=3.3.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (3.3.3)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from presidio-image-redactor) (3.8.3)
# Requirement already satisfied: opencv-python<5.0.0,>=4.0.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (4.11.0.86)
# Requirement already satisfied: pillow>=9.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (10.4.0)
# Collecting presidio-analyzer>=1.9.0 (from presidio-image-redactor)
#   Using cached presidio_analyzer-2.2.357-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydicom>=2.3.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (3.0.1)
# Requirement already satisfied: pypng>=0.20220715.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (0.20220715.0)
# Requirement already satisfied: pytesseract<0.4,>=0.3.7 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (0.3.13)
# Requirement already satisfied: python-gdcm>=3.0.24.1 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (3.0.24.1)
# Requirement already satisfied: azure-core>=1.23.0 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (1.32.0)
# Requirement already satisfied: msrest>=0.6.21 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (0.7.1)
# Requirement already satisfied: azure-common>=1.1 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (4.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->presidio-image-redactor) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->presidio-image-redactor) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (2.9.0.post0)
# Requirement already satisfied: phonenumbers<9.0.0,>=8.12 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-analyzer>=1.9.0->presidio-image-redactor) (8.13.55)
# Requirement already satisfied: pyyaml in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-analyzer>=1.9.0->presidio-image-redactor) (6.0.1)
# Requirement already satisfied: regex in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-analyzer>=1.9.0->presidio-image-redactor) (2024.9.11)
# Requirement already satisfied: spacy!=3.7.0,<4.0.0,>=3.4.4 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-analyzer>=1.9.0->presidio-image-redactor) (3.8.4)
# Requirement already satisfied: tldextract in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-analyzer>=1.9.0->presidio-image-redactor) (5.1.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (2024.2.2)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\saarthak\anaconda3\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (0.7.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\saarthak\anaconda3\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (2.0.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.12.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (4.66.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.6.4)
# Requirement already satisfied: jinja2 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (69.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.5.0)
# Requirement already satisfied: idna in c:\users\saarthak\anaconda3\lib\site-packages (from tldextract->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.7)
# Requirement already satisfied: requests-file>=1.4 in c:\users\saarthak\anaconda3\lib\site-packages (from tldextract->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from tldextract->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.13.3)
# Requirement already satisfied: language-data>=1.2 in c:\users\saarthak\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\saarthak\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saarthak\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (2.2.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\saarthak\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (3.2.2)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in c:\users\saarthak\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\saarthak\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.1.5)
# Requirement already satisfied: colorama in c:\users\saarthak\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.4.6)
# Requirement already satisfied: typer-slim==0.12.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.12.0)
# Requirement already satisfied: typer-cli==0.12.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.12.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from typer-slim==0.12.0->typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\saarthak\anaconda3\lib\site-packages (from typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\saarthak\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\saarthak\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saarthak\anaconda3\lib\site-packages (from jinja2->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.1.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\saarthak\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\saarthak\anaconda3\lib\site-packages (from rich>=10.11.0->typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\saarthak\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.1.0)
# Using cached presidio_image_redactor-0.0.55-py3-none-any.whl (34 kB)
# Using cached presidio_analyzer-2.2.357-py3-none-any.whl (112 kB)
# Installing collected packages: presidio-analyzer, presidio-image-redactor
# Successfully installed presidio-analyzer-2.2.357 presidio-image-redactor-0.0.55

# %%
# %pip install presidio-image-redactor
# Out:
# Requirement already satisfied: presidio-image-redactor in c:\users\saarthak\anaconda3\lib\site-packages (0.0.55)
# Requirement already satisfied: azure-ai-formrecognizer<4.0.0,>=3.3.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (3.3.3)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from presidio-image-redactor) (3.8.3)
# Requirement already satisfied: opencv-python<5.0.0,>=4.0.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (4.11.0.86)
# Requirement already satisfied: pillow>=9.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (10.4.0)
# Requirement already satisfied: presidio-analyzer>=1.9.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (2.2.357)
# Requirement already satisfied: pydicom>=2.3.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (3.0.1)
# Requirement already satisfied: pypng>=0.20220715.0 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (0.20220715.0)
# Requirement already satisfied: pytesseract<0.4,>=0.3.7 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (0.3.13)
# Requirement already satisfied: python-gdcm>=3.0.24.1 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-image-redactor) (3.0.24.1)
# Requirement already satisfied: azure-core>=1.23.0 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (1.32.0)
# Requirement already satisfied: msrest>=0.6.21 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (0.7.1)
# Requirement already satisfied: azure-common>=1.1 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (4.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->presidio-image-redactor) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->presidio-image-redactor) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saarthak\anaconda3\lib\site-packages (from matplotlib>=3.6->presidio-image-redactor) (2.9.0.post0)
# Requirement already satisfied: phonenumbers<9.0.0,>=8.12 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-analyzer>=1.9.0->presidio-image-redactor) (8.13.55)
# Requirement already satisfied: pyyaml in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-analyzer>=1.9.0->presidio-image-redactor) (6.0.1)
# Requirement already satisfied: regex in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-analyzer>=1.9.0->presidio-image-redactor) (2024.9.11)
# Requirement already satisfied: spacy!=3.7.0,<4.0.0,>=3.4.4 in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-analyzer>=1.9.0->presidio-image-redactor) (3.8.4)
# Requirement already satisfied: tldextract in c:\users\saarthak\anaconda3\lib\site-packages (from presidio-analyzer>=1.9.0->presidio-image-redactor) (5.1.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\saarthak\anaconda3\lib\site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (2024.2.2)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\saarthak\anaconda3\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (0.7.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\saarthak\anaconda3\lib\site-packages (from msrest>=0.6.21->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (2.0.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.12.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (4.66.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.6.4)
# Requirement already satisfied: jinja2 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (69.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\saarthak\anaconda3\lib\site-packages (from spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.5.0)
# Requirement already satisfied: idna in c:\users\saarthak\anaconda3\lib\site-packages (from tldextract->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.7)
# Requirement already satisfied: requests-file>=1.4 in c:\users\saarthak\anaconda3\lib\site-packages (from tldextract->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from tldextract->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.13.3)
# Requirement already satisfied: language-data>=1.2 in c:\users\saarthak\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\saarthak\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saarthak\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (2.2.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\saarthak\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer<4.0.0,>=3.3.0->presidio-image-redactor) (3.2.2)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in c:\users\saarthak\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.2.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\saarthak\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.1.5)
# Requirement already satisfied: colorama in c:\users\saarthak\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.4.6)
# Requirement already satisfied: typer-slim==0.12.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.12.0)
# Requirement already satisfied: typer-cli==0.12.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.12.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from typer-slim==0.12.0->typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\saarthak\anaconda3\lib\site-packages (from typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\saarthak\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\saarthak\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saarthak\anaconda3\lib\site-packages (from jinja2->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.1.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\saarthak\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\saarthak\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\saarthak\anaconda3\lib\site-packages (from rich>=10.11.0->typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\saarthak\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer-slim[standard]==0.12.0->typer<1.0.0,>=0.3.0->spacy!=3.7.0,<4.0.0,>=3.4.4->presidio-analyzer>=1.9.0->presidio-image-redactor) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
# First install the package using: pip install presidio-image-redactor
from presidio_image_redactor import ImageRedactorEngine
from pydicom.pixels import apply_voi_lut
spacy.load('en_core_web_lg')

# Get the image to redact using PIL lib (pillow)
image = Image.open("/ss.png")

# Initialize the engine
engine = ImageRedactorEngine()

# Redact the image with pink color
redacted_image = engine.redact(image, (255, 192, 203))

# save the redacted image 
redacted_image.save("new_image.png")
# uncomment to open the image for viewing
# redacted_image.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 from PIL import Image
#       2 # First install the package using: pip install presidio-image-redactor
# ----> 3 from presidio_image_redactor import ImageRedactorEngine
#       4 from pydicom.pixels import apply_voi_lut
#       5 spacy.load('en_core_web_lg')
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\presidio_image_redactor\__init__.py:9
#       7 from .tesseract_ocr import TesseractOCR
#       8 from .document_intelligence_ocr import DocumentIntelligenceOCR
# ----> 9 from .bbox import BboxProcessor
#      10 from .image_processing_engine import ImagePreprocessor
#      11 from .image_analyzer_engine import ImageAnalyzerEngine
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\presidio_image_redactor\bbox.py:3
#       1 from typing import Dict, List, Tuple, Union
# ----> 3 from presidio_image_redactor.entities import ImageRecognizerResult
#       6 class BboxProcessor:
#       7     """Common module for general bounding box operators."""
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\presidio_image_redactor\entities\__init__.py:3
#       1 """Image Redactor entities."""
# ----> 3 from .image_recognizer_result import ImageRecognizerResult
#       4 from .invalid_exception import InvalidParamError
#       6 __all__ = [
#       7     "ImageRecognizerResult",
#       8     "InvalidParamError",
#       9 ]
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\presidio_image_redactor\entities\image_recognizer_result.py:1
# ----> 1 from presidio_analyzer import RecognizerResult
#       4 class ImageRecognizerResult(RecognizerResult):
#       5     """
#       6     ImageRecognizerResult represents the results of analysing the image.
#       7
#    (...)
#      15     :param height: height of the bbox in pixels
#      16     """
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\presidio_analyzer\__init__.py:9
#       7 from presidio_analyzer.recognizer_result import RecognizerResult
#       8 from presidio_analyzer.dict_analyzer_result import DictAnalyzerResult
# ----> 9 from presidio_analyzer.entity_recognizer import EntityRecognizer
#      10 from presidio_analyzer.local_recognizer import LocalRecognizer
#      11 from presidio_analyzer.pattern import Pattern
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\presidio_analyzer\entity_recognizer.py:6
#       3 from typing import Dict, List, Optional
#       5 from presidio_analyzer import RecognizerResult
# ----> 6 from presidio_analyzer.nlp_engine import NlpArtifacts
#       8 logger = logging.getLogger("presidio-analyzer")
#      11 class EntityRecognizer:
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\presidio_analyzer\nlp_engine\__init__.py:4
#       1 """NLP engine package. Performs text pre-processing."""
#       3 from .ner_model_configuration import NerModelConfiguration
# ----> 4 from .nlp_artifacts import NlpArtifacts
#       5 from .nlp_engine import NlpEngine
#       6 from .spacy_nlp_engine import SpacyNlpEngine
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\presidio_analyzer\nlp_engine\nlp_artifacts.py:4
#       1 import json
#       2 from typing import List, Optional
# ----> 4 from spacy.tokens import Doc, Span
#       7 class NlpArtifacts:
#       8     """
#       9     NlpArtifacts is an abstraction layer over the results of an NLP pipeline.
#      10
#    (...)
#      20     :param scores: Entity confidence scores
#      21     """
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\spacy\__init__.py:13
#      10 # These are imported as part of the API
#      11 from thinc.api import Config, prefer_gpu, require_cpu, require_gpu  # noqa: F401
# ---> 13 from . import pipeline  # noqa: F401
#      14 from . import util
#      15 from .about import __version__  # noqa: F401
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\spacy\pipeline\__init__.py:1
# ----> 1 from .attributeruler import AttributeRuler
#       2 from .dep_parser import DependencyParser
#       3 from .edit_tree_lemmatizer import EditTreeLemmatizer
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\spacy\pipeline\attributeruler.py:8
#       6 from .. import util
#       7 from ..errors import Errors
# ----> 8 from ..language import Language
#       9 from ..matcher import Matcher
#      10 from ..scorer import Scorer
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\spacy\language.py:46
#      44 from .lang.tokenizer_exceptions import BASE_EXCEPTIONS, URL_MATCH
#      45 from .lookups import load_lookups
# ---> 46 from .pipe_analysis import analyze_pipes, print_pipe_analysis, validate_attrs
#      47 from .schemas import (
#      48     ConfigSchema,
#      49     ConfigSchemaInit,
#    (...)
#      52     validate_init_settings,
#      53 )
#      54 from .scorer import Scorer
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\spacy\pipe_analysis.py:6
#       3 from wasabi import msg
#       5 from .errors import Errors
# ----> 6 from .tokens import Doc, Span, Token
#       7 from .util import dot_to_dict
#       9 if TYPE_CHECKING:
#      10     # This lets us add type hints for mypy etc. without causing circular imports
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\spacy\tokens\__init__.py:1
# ----> 1 from ._serialize import DocBin
#       2 from .doc import Doc
#       3 from .morphanalysis import MorphAnalysis
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\spacy\tokens\_serialize.py:14
#      12 from ..errors import Errors
#      13 from ..util import SimpleFrozenList, ensure_path
# ---> 14 from ..vocab import Vocab
#      15 from ._dict_proxies import SpanGroups
#      16 from .doc import DOCBIN_ALL_ATTRS as ALL_ATTRS
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\spacy\vocab.pyx:1, in init spacy.vocab()
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\spacy\tokens\doc.pyx:49, in init spacy.tokens.doc()
#
# File c:\Users\Saarthak\anaconda3\Lib\site-packages\spacy\schemas.py:195
#     191         obj = converted
#     192     return validate(TokenPatternSchema, {"pattern": obj})
# --> 195 class TokenPatternString(BaseModel):
#     196     REGEX: Optional[Union[StrictStr, "TokenPatternString"]] = Field(None, alias="regex")
#     197     IN: Optional[List[StrictStr]] = Field(None, alias="in")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydantic\v1\main.py:286, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     284 cls.__signature__ = ClassAttribute('__signature__', generate_model_signature(cls.__init__, fields, config))
#     285 if resolve_forward_refs:
# --> 286     cls.__try_update_forward_refs__()
#     288 # preserve `__set_name__` protocol defined in https://peps.python.org/pep-0487
#     289 # for attributes not in `new_namespace` (e.g. private attributes)
#     290 for name, obj in namespace.items():
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydantic\v1\main.py:807, in BaseModel.__try_update_forward_refs__(cls, **localns)
#     801 @classmethod
#     802 def __try_update_forward_refs__(cls, **localns: Any) -> None:
#     803     """
#     804     Same as update_forward_refs but will not raise exception
#     805     when forward references are not defined.
#     806     """
# --> 807     update_model_forward_refs(cls, cls.__fields__.values(), cls.__config__.json_encoders, localns, (NameError,))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydantic\v1\typing.py:554, in update_model_forward_refs(model, fields, json_encoders, localns, exc_to_suppress)
#     552 for f in fields:
#     553     try:
# --> 554         update_field_forward_refs(f, globalns=globalns, localns=localns)
#     555     except exc_to_suppress:
#     556         pass
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydantic\v1\typing.py:529, in update_field_forward_refs(field, globalns, localns)
#     527 if field.sub_fields:
#     528     for sub_f in field.sub_fields:
# --> 529         update_field_forward_refs(sub_f, globalns=globalns, localns=localns)
#     531 if field.discriminator_key is not None:
#     532     field.prepare_discriminated_union_sub_fields()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydantic\v1\typing.py:520, in update_field_forward_refs(field, globalns, localns)
#     518 if field.type_.__class__ == ForwardRef:
#     519     prepare = True
# --> 520     field.type_ = evaluate_forwardref(field.type_, globalns, localns or None)
#     521 if field.outer_type_.__class__ == ForwardRef:
#     522     prepare = True
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pydantic\v1\typing.py:66, in evaluate_forwardref(type_, globalns, localns)
#      63 def evaluate_forwardref(type_: ForwardRef, globalns: Any, localns: Any) -> Any:
#      64     # Even though it is the right signature for python 3.9, mypy complains with
#      65     # `error: Too many arguments for "_evaluate" of "ForwardRef"` hence the cast...
# ---> 66     return cast(Any, type_)._evaluate(globalns, localns, set())
#
# TypeError: ForwardRef._evaluate() missing 1 required keyword-only argument: 'recursive_guard'
